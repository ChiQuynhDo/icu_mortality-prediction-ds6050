# %% [markdown]
# **Building LSTM Model**

# %%
import pandas as pd
from os import listdir
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import RandomizedSearchCV
from sklearn.base import BaseEstimator

import tensorflow as tf
#from tensorflow import keras

# %% [markdown]
# Loading data

# %%
data_path = r'../data/final_data'

# Files to read
data_files = listdir(data_path)

# Load data
data = pd.concat([pd.read_csv(data_path + '/' + file) for file in data_files]).drop(columns=['endtime'])

# %%
data.head()
# Out:
#   insurance   race marital_status gender  anchor_age value  amount amountuom  \
# 0  Medicare  OTHER         SINGLE      F          53   NaN     3.3    mmol/L
# 1  Medicare  OTHER         SINGLE      F          53   NaN   421.0      mmHg
# 2  Medicare  OTHER         SINGLE      F          53   NaN     2.8    mmol/L
# 3  Medicare  OTHER         SINGLE      F          53   NaN     3.1    mmol/L
# 4  Medicare  OTHER         SINGLE      F          53   NaN   384.0      mmHg
#
#                   label   Died       Unique Stay  sequence_num
# 0           Lactic Acid  False  1000201323581541             1
# 1  Arterial O2 pressure  False  1000201323581541             2
# 2           Lactic Acid  False  1000201323581541             3
# 3           Lactic Acid  False  1000201323581541             4
# 4  Arterial O2 pressure  False  1000201323581541             5

# %% [markdown]
# Verifying that data includes only CABG patients

# %%
CABG_ICDS = ['0210093', '0210098', '0210099', '021009C', '021009F', '021009W',
'02100A3', '02100A8', '02100A9', '02100AC', '02100AF', '02100AW',
'02100J3', '02100J8', '02100J9', '02100JC', '02100JF', '02100JW',
'02100K3', '02100K8', '02100K9', '02100KC', '02100KF', '02100KW',
'02100Z3', '02100Z8', '02100Z9', '02100ZC', '02100ZF',
'0211093', '0211098', '0211099', '021109C', '021109F', '021109W',
'02110A3', '02110A8', '02110A9', '02110AC', '02110AF', '02110AW',
'02110J3', '02110J8', '02110J9', '02110JC', '02110JF', '02110JW',
'02110K3', '02110K8', '02110K9', '02110KC', '02110KF', '02110KW',
'02110Z3', '02110Z8', '02110Z9', '02110ZC', '02110ZF',
'0212093', '0212098', '0212099', '021209C', '021209F', '021209W',
'02120A3', '02120A8', '02120A9', '02120AC', '02120AF', '02120AW',
'02120J3', '02120J8', '02120J9', '02120JC', '02120JF', '02120JW',
'02120K3', '02120K8', '02120K9', '02120KC', '02120KF', '02120KW',
'02120Z3', '02120Z8', '02120Z9', '02120ZC', '02120ZF',
'0213093', '0213098', '0213099', '021309C', '021309F', '021309W',
'02130A3', '02130A8', '02130A9', '02130AC', '02130AF', '02130AW',
'02130J3', '02130J8', '02130J9', '02130JC', '02130JF', '02130JW',
'02130K3', '02130K8', '02130K9', '02130KC', '02130KF', '02130KW',
'02130Z3', '02130Z8', '02130Z9', '02130ZC', '02130ZF',
'3610', '3611', '3612', '3613', '3614', '3615', '3616', '3617', '3619']

# %%
#cabg_pts = pd.read_csv('B:/Databases/MIMIC-IV/CABG-filtered/cabg_pts.csv')

# %%
# # Filter data to only include CABG patients
# cabg_pts[cabg_pts.icd_code.isin(CABG_ICDS)]

# # Unique patient IDs
# cabg_pts.subject_id.nunique() # 5647 unique patients

# Create unique stay ID
# unique_stay = cabg_pts.subject_id.astype(str) + cabg_pts.hadm_id.astype(str)
# unique_stay = unique_stay.to_list()

# Number of patients in the data
data.shape[0]
# Out:
# 1214970

# %%
# Number of patients in the data that are CABG patients
#data['Unique Stay'].astype(str).isin(unique_stay).sum()

# %% [markdown]
# ### Data Preprocessing

# %%
# Recoding race data
data['race_new']  = data.race.replace({
                              'WHITE': 'White',
                              'WHITE - OTHER EUROPEAN': 'White',
                              'WHITE - RUSSIAN': 'White',
                              'WHITE - EASTERN EUROPEAN': 'White',
                              'PORTUGUESE': 'White',
                              'WHITE - BRAZILIAN': 'White',
                              # Black
                              'BLACK/AFRICAN AMERICAN': 'Black',
                              'BLACK/AFRICAN': 'Black',
                              'HISPANIC/LATINO - GUATEMALAN': 'Black',
                              # Asian
                              'ASIAN - ASIAN INDIAN': 'Asian',
                              'ASIAN': 'Asian',
                              'ASIAN - CHINESE': 'Asian',
                              'ASIAN - SOUTH EAST ASIAN': 'Asian',
                              'ASIAN - KOREAN': 'Asian',
                              # Hispanic
                              'HISPANIC/LATINO - PUERTO RICAN': 'Hispanic',
                              'HISPANIC/LATINO - DOMINICAN': 'Hispanic',
                              'HISPANIC OR LATINO': 'Hispanic',
                              'HISPANIC': 'Hispanic',
                              'HISPANIC/LATINO - CUBAN': 'Hispanic',
                              'HISPANIC/LATINO - SALVADORAN': 'Hispanic',
                              'SOUTH AMERICAN': 'Hispanic',
                              'HISPANIC/LATINO - COLUMBIAN': 'Hispanic',
                              'HISPANIC/LATINO - CUBAN': 'Hispanic',
                              'HISPANIC/LATINO - HONDURAN': 'Hispanic',
                              'HISPANIC/LATINO - CENTRAL AMERICAN': 'Hispanic',
                              'HISPANIC/LATINO - MEXICAN': 'Hispanic',
                              # Native American/Pacific Islander
                              'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER': 'Native American',
                              'AMERICAN INDIAN/ALASKA NATIVE': 'Native American',
                              'BLACK/CAPE VERDEAN': 'Black',
                              'BLACK/CARIBBEAN ISLAND' : 'Black',
                              # Other
                              'OTHER': 'Other',
                              'MULTIPLE RACE/ETHNICITY': 'Other',
                              # Unknown
                              'UNABLE TO OBTAIN': np.nan,
                              'UNKNOWN': np.nan,
                              'PATIENT DECLINED TO ANSWER': np.nan,
                              })

data.race = data.race_new
data.drop(['race_new'], axis = 1, inplace = True)

data.race.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Other
# 1        Other
# 2        Other
# 3        Other
# 4        Other
#          ...
# 99995    White
# 99996    White
# 99997    White
# 99998    White
# 99999    White
# Name: race, Length: 1214970, dtype: object>

# %%
# Checking for discrepancies in the race data

# Creating data for patient ID
data['subject_id'] = data['Unique Stay'].astype(str).str[0:8]

# Checking if all race data is the same for each patient
data.groupby('subject_id').race.nunique().value_counts()
# Out:
# race
# 1    4533
# 0     813
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning up the group of variables `value`, `amount`, `amountuom`, `label`.**

# %%
data.label.value_counts()
# Out:
# label
# Heart Rate                      526542
# Arterial Blood Pressure mean    336641
# Inspired O2 Fraction             71942
# Arterial O2 pressure             61075
# Ventilator Type                  41940
# Platelet Count                   36745
# Ventilator Mode                  34464
# Creatinine (serum)               34050
# Lactic Acid                      31799
# Norepinephrine                   25894
# Epinephrine                       8281
# Total Bilirubin                   4365
# Dobutamine                         634
# Dopamine                           591
# Epinephrine.                         7
# Name: count, dtype: int64

# %% [markdown]
# There are 2 label values for epinephrine: 'Epinephrine' and 'Epinephrine.'. We will combine these into one label value.
# Also, there are 2 different units of measure for epinephrine: 'mcg' and 'mg'. We will convert all values to 'mg'. But we need to make sure that the values that are coded as mcg are actually mcg and not mg (the values for mcg and mg should different by a factor of 1000).

# %%
# Remove the '.' from 'Epinephrine.' in the 'label' column
data.loc[data.label == 'Epinephrine.', 'label'] = 'Epinephrine'

# Convert 'amount' from mcg to mg and change 'amountuom' to 'mg'
data.loc[(data.label == 'Epinephrine') & (data.amountuom == 'mcg'), 'amount'] /= 1000
data.loc[(data.label == 'Epinephrine') & (data.amountuom == 'mcg'), 'amountuom'] = 'mg'

# %%
data.label.value_counts()
# Out:
# label
# Heart Rate                      526542
# Arterial Blood Pressure mean    336641
# Inspired O2 Fraction             71942
# Arterial O2 pressure             61075
# Ventilator Type                  41940
# Platelet Count                   36745
# Ventilator Mode                  34464
# Creatinine (serum)               34050
# Lactic Acid                      31799
# Norepinephrine                   25894
# Epinephrine                       8288
# Total Bilirubin                   4365
# Dobutamine                         634
# Dopamine                           591
# Name: count, dtype: int64

# %%
# Making sure that units and values are consistent
print('Heart rate: ', data[data.label == 'Heart Rate'].amountuom.value_counts(), '\n')

print('MAP: ', data[data.label == 'Arterial Blood Pressure mean'].amountuom.value_counts(), '\n')

print('FiO2: ', data[data.label == 'Inspired O2 Fraction'].amountuom.value_counts(), '\n')

print('PaO2: ', data[data.label == 'Arterial O2 pressure'].amountuom.value_counts(), '\n')

print('Ventilator type: ', data[data.label == 'Ventilator Type'].amountuom.value_counts(), '\n')

print('Ventilator Mode: ', data[data.label == 'Ventilator Mode'].amountuom.value_counts(), '\n')

print('Platelet Count: ', data[data.label == 'Platelet Count'].amountuom.value_counts(), '\n')

print('Creatinine (serum): ', data[data.label == 'Creatinine (serum)'].amountuom.value_counts(), '\n')

print('Lactic Acid: ', data[data.label == 'Lactic Acid'].amountuom.value_counts(), '\n')

print('Norepinephrine: ', data[data.label == 'Norepinephrine'].amountuom.value_counts(), '\n')

print('Epinephrine: ', data[data.label == 'Epinephrine'].amountuom.value_counts(), '\n')

print('Total Bilirubin: ', data[data.label == 'Total Bilirubin'].amountuom.value_counts(), '\n')

print('Dobutamine: ', data[data.label == 'Dobutamine'].amountuom.value_counts(), '\n')

print('Dopamine: ', data[data.label == 'Dopamine'].amountuom.value_counts(), '\n')
# Out:
# Heart rate:  amountuom
# bpm    526542
# Name: count, dtype: int64
#
# MAP:  amountuom
# mmHg    336641
# Name: count, dtype: int64
#
# FiO2:  Series([], Name: count, dtype: int64)
#
# PaO2:  amountuom
# mmHg    61075
# Name: count, dtype: int64
#
# Ventilator type:  Series([], Name: count, dtype: int64)
#
# Ventilator Mode:  Series([], Name: count, dtype: int64)
#
# Platelet Count:  amountuom
# K/uL    36739
# Name: count, dtype: int64
#
# Creatinine (serum):  amountuom
# mg/dL    34044
# Name: count, dtype: int64
#
# Lactic Acid:  amountuom
# mmol/L    31798
# Name: count, dtype: int64
#
# Norepinephrine:  amountuom
# mg    25894
# Name: count, dtype: int64
#
# Epinephrine:  amountuom
# mg    8288
# Name: count, dtype: int64
#
# Total Bilirubin:  amountuom
# mg/dL    4365
# Name: count, dtype: int64
#
# Dobutamine:  amountuom
# mg    634
# Name: count, dtype: int64
#
# Dopamine:  amountuom
# mg    591
# Name: count, dtype: int64

# %% [markdown]
# Encode categorical features

# %%
label_encoder = LabelEncoder()

# Encode categorical columns
categorical_columns = ['insurance', 'race', 'marital_status', 'gender', 'value', 'amountuom', 'amount']
for col in categorical_columns:
    data[col] = label_encoder.fit_transform(data[col].astype(str))

data.drop(columns = ['subject_id'], inplace = True)

# %%
# Encode target variable `Died` (binary classification: 0 = Alive, 1 = Died)
data['Died'] = label_encoder.fit_transform(data['Died'])

# Sort by Unique Stay and sequence number to get events in correct order
data.sort_values(by=['Unique Stay', 'sequence_num'], inplace=True)

# %%
# Number of observations
print('Number of observations: ', data['Unique Stay'].nunique())
# Out:
# Number of observations:  5361

# %%
# Create sequences of features for each Unique Stay
sequence_data = []
sequence_labels = []

unique_stays = data['Unique Stay'].unique()

# %% [markdown]
# Iterate over unique stays

# %%
for stay in unique_stays:
    stay_data = data[data['Unique Stay'] == stay]
    stay_features = stay_data[['insurance', 'race', 'marital_status', 'gender', 'anchor_age', 'value', 'amount', 'amountuom']].values
    stay_label = stay_data['Died'].values[-1]  # Use the last event to define the label
    
    # Add the sequence and its corresponding label
    sequence_data.append(stay_features)
    sequence_labels.append(stay_label)

# %% [markdown]
# Pad sequences to ensure uniform input length

# %%
import keras

# %%
#from tensorflow.keras.utils import pad_sequences
sequence_data = keras.utils.pad_sequences(sequence_data, padding='post', dtype='float32', maxlen=50)  # Adjust maxlen as needed

# %%
# Convert labels to numpy array
sequence_labels = np.array(sequence_labels)

# %% [markdown]
# Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(sequence_data, sequence_labels, test_size=0.2, random_state=42)

# %% [markdown]
# Define custom wrapper for the Keras model to use with RandomizedSearchCV

# %%
from keras import layers, Sequential

# %%
class KerasModelWrapper(BaseEstimator):
    def __init__(self, learning_rate=0.001, gru_units=64, dropout_rate=0.2, epochs=10, batch_size=32):
        self.learning_rate = learning_rate
        self.gru_units = gru_units
        self.dropout_rate = dropout_rate
        self.epochs = epochs
        self.batch_size = batch_size
        self.model = None
    def create_model(self):
        model = Sequential([
            layers.InputLayer(input_shape=(X_train.shape[1], X_train.shape[2])), 
            layers.Masking(mask_value=0.0),
            layers.GRU(self.gru_units, return_sequences=False, dropout=self.dropout_rate),
            layers.Dense(1, activation='sigmoid')
        ])
        model.compile(optimizer=Adam(learning_rate=self.learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
        return model
    def fit(self, X, y):
        self.model = self.create_model()
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self
    def predict(self, X):
        return self.model.predict(X)
    def score(self, X, y):
        return self.model.evaluate(X, y, verbose=0)[1]

# %% [markdown]
# Instantiate the model wrapper

# %%
model = KerasModelWrapper()

# %% [markdown]
# Define the parameter grid for tuning

# %%
param_grid = {
    'learning_rate': [0.001, 0.01, 0.1],
    'gru_units': [32, 64, 128],
    'dropout_rate': [0.2, 0.3, 0.5],
    'batch_size': [16, 32, 64],
    'epochs': [10, 20, 50]
}

# %% [markdown]
# RandomizedSearchCV to tune hyperparameters

# %%
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=10, cv=3, verbose=2, n_jobs=-1, random_state=42)

# %% [markdown]
# Perform the search

# %%
random_search_result = random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# /home/melmoheb/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.487697   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.487697   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.496607   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.504121   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.504118   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.518722   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.522017   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.541088   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.552080   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.554642   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.560118   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.569312   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.572755   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.593510   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.593721   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.594797   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.594983   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.595205   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.595288   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731200711.599439   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.625135   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.625234   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.626714   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.626801   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.642306   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.642691   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.642897   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.644588   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.644698   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.644720   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.678262   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.678684   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.691653   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.691686   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.691745   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.692030   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.720014   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.720621   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.720693   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.720171   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723311   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723455   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723577   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723607   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723649   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723683   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.723821   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.740042   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.740232   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.756952   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.757072   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.757093   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.762039   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.762535   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.762659   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.767162   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.767292   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.785541   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.785664   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.785682   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.797305   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.797559   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.797600   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.797694   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.805366   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.805549   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.805589   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.810540   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.810678   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.810824   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.810919   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.808745   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.811529   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.811604   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.820316   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.820410   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.820509   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.820533   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.820555   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.824998   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.825158   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.825179   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.828295   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.828367   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.828385   18573 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.829248   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.829392   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.832417   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.832663   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.834945   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.835092   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.836157   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.836222   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.836242   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.836843   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837144   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837419   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837577   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837636   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837656   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837804   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.837827   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.841173   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.841375   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.841397   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.847573   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.847671   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.847687   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.848650   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.849002   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.849265   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.849344   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.849358   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.849363   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.850402   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.850514   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.850631   18571 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.853875   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.853942   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200711.854075   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.573834   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.573834   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.573874   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.573943   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.573956   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.573958: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-09 20:05:12.573969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.574102   18584 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.574106   18579 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.574162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2024-11-09 20:05:12.574162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.574649   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.574694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.574789   18578 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.574839: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.576704   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.576855   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.576873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.576937   18570 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.577005: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.577797   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.578207   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.578261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.578411   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.578670   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.578705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.578771   18582 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.578823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.582814   18586 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.582950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.599243   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.599503   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.599576   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.599585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.599627   18583 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.599651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.599886   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.600045   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.600056: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.600096   18577 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.600116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.600720   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.600778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.600894   18589 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.600931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.603846   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.604025   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.604178   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.604227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.604337   18574 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.604415: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.604441   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.604462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.604579   18587 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.604637: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.604958   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.605402   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.605410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.605445   18588 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.605463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.611234   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.611234   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.611405   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.611430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.611509   18576 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.611552   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.611528   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.611577: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-09 20:05:12.611581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.611628   18575 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.611640   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.611655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2024-11-09 20:05:12.611680: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.611766   18572 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.611815: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.615674   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.615854   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.615867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.615913   18585 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.615957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.624255   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.624452   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.624476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731200712.624563   18580 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.624627: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6687 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1
# I0000 00:00:1731200712.625714   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731200712.626226   18581 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-09 20:05:12.626607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# ...
# Status: INTERNAL: out of memory
# 2024-11-09 20:05:20.847679: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.80MiB (1892352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.848181: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.62MiB (1703168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.848753: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.46MiB (1532928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.849051: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.80MiB (1892352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.849596: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.62MiB (1703168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.849609: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 2.00MiB (2102528 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.850255: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.80MiB (1892352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.850813: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.62MiB (1703168 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.850824: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.32MiB (1379840 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.851566: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.18MiB (1241856 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.851923: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.46MiB (1532928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.852439: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.32MiB (1379840 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.852960: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.18MiB (1241856 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.853412: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.46MiB (1532928 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.853821: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.07MiB (1117696 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.854268: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 982.5KiB (1006080 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.854677: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 884.2KiB (905472 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.855278: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.07MiB (1117696 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.855753: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.32MiB (1379840 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.855960: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 796.0KiB (815104 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.856525: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 716.5KiB (733696 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.857059: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 645.0KiB (660480 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.857506: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 580.5KiB (594432 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.857671: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 982.5KiB (1006080 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.858221: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 884.2KiB (905472 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.858811: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 796.0KiB (815104 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.858934: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.18MiB (1241856 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.859717: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 522.5KiB (535040 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.860217: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 470.2KiB (481536 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.860877: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 716.5KiB (733696 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.861101: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 1.07MiB (1117696 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.861559: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 982.5KiB (1006080 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:20.862366: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 423.2KiB (433408 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# [CV] END batch_size=64, dropout_rate=0.2, epochs=20, gru_units=64, learning_rate=0.01; total time=   9.5s
# [CV] END batch_size=64, dropout_rate=0.2, epochs=20, gru_units=64, learning_rate=0.01; total time=   9.5s
# [CV] END batch_size=16, dropout_rate=0.2, epochs=10, gru_units=128, learning_rate=0.001; total time=  11.5s
# 2024-11-09 20:05:35.756324: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 6.53GiB (7011437568 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:36.003386: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 5.88GiB (6310293504 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:36.068934: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 6.53GiB (7011167232 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# [CV] END batch_size=16, dropout_rate=0.2, epochs=10, gru_units=128, learning_rate=0.001; total time=  24.7s
# 2024-11-09 20:05:36.255545: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 5.88GiB (6310050304 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:50.338444: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 5.29GiB (5679264256 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# [CV] END batch_size=64, dropout_rate=0.5, epochs=20, gru_units=128, learning_rate=0.01; total time=  39.3s
# [CV] END batch_size=64, dropout_rate=0.3, epochs=50, gru_units=128, learning_rate=0.1; total time=  39.4s
# 2024-11-09 20:05:51.539918: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 5.29GiB (5679045120 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# [CV] END batch_size=32, dropout_rate=0.5, epochs=20, gru_units=128, learning_rate=0.1; total time=  42.0s
# 2024-11-09 20:05:53.400461: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 4.76GiB (5111337472 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:53.467902: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 4.76GiB (5111140352 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# 2024-11-09 20:05:54.366955: I external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:1578] failed to allocate 4.28GiB (4600203776 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# [CV] END batch_size=16, dropout_rate=0.2, epochs=50, gru_units=128, learning_rate=0.001; total time=  43.0s
# [CV] END batch_size=64, dropout_rate=0.2, epochs=20, gru_units=64, learning_rate=0.01; total time=  43.2s
# [CV] END batch_size=64, dropout_rate=0.5, epochs=50, gru_units=64, learning_rate=0.01; total time=  43.7s
# [CV] END batch_size=64, dropout_rate=0.3, epochs=50, gru_units=128, learning_rate=0.1; total time=  44.8s
# [CV] END batch_size=16, dropout_rate=0.2, epochs=10, gru_units=128, learning_rate=0.001; total time=  45.0s
# [CV] END batch_size=64, dropout_rate=0.5, epochs=20, gru_units=128, learning_rate=0.01; total time=  45.9s
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 random_search_result = random_search.fit(X_train, y_train)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1959, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1957 def _run_search(self, evaluate_candidates):
#    1958     """Search n_iter candidates from param_distributions"""
# -> 1959     evaluate_candidates(
#    1960         ParameterSampler(
#    1961             self.param_distributions, self.n_iter, random_state=self.random_state
#    1962         )
#    1963     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File ~/miniconda3/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File ~/miniconda3/lib/python3.12/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# TerminatedWorkerError: A worker process managed by the executor was unexpectedly terminated. This could be caused by a segmentation fault while calling the function or by an excessive memory usage causing the Operating System to kill the worker.
#
# The exit codes of the workers are {SIGABRT(-6)}

# %% [markdown]
# Best parameters and score

# %%
print("Best Hyperparameters:", random_search_result.best_params_)
print("Best Accuracy:", random_search_result.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print("Best Hyperparameters:", random_search_result.best_params_)
#       2 print("Best Accuracy:", random_search_result.best_score_)
#
# NameError: name 'random_search_result' is not defined

# %% [markdown]
# Evaluate the best model on the test set

# %%
best_model = random_search_result.best_estimator_
test_acc = best_model.score(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 best_model = random_search_result.best_estimator_
#       2 test_acc = best_model.score(X_test, y_test)
#       3 print(f'Test Accuracy: {test_acc:.4f}')
#
# NameError: name 'random_search_result' is not defined

# %% [markdown]
# Save the best model

# %%
best_model = random_search_result.best_estimator_

# %% [markdown]
# Save the best model to a file

# %%
model_save_path = 'gru_best_model.keras'
best_model.model.save(model_save_path)

# %%
print(f"Best model saved at: {model_save_path}")

# %% [markdown]
# Evaluate the best model on the test set

# %%
test_acc = best_model.score(X_test, y_test)
print(f'Test Accuracy: {test_acc:.4f}')

# %% [markdown]
# Load the saved model and re-evaluate on the test set

# %%
loaded_model = load_model(model_save_path)
loaded_test_loss, loaded_test_acc = loaded_model.evaluate(X_test, y_test, verbose=0)

# %%
print(f"Loaded Model Test Accuracy: {loaded_test_acc:.4f}")
